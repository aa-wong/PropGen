# %%
# import libs
try:
    from PIL import Image
except ImportError:
    import Image
import cv2
import pytesseract
import os
import numpy as np
import pandas as pd
import re
from pdf2image import convert_from_bytes

# %%
# Some help functions 
def get_conf(page_gray):
    '''return a average confidence value of OCR result '''
    df = pytesseract.image_to_data(page_gray,output_type='data.frame')
    df.drop(df[df.conf==-1].index.values,inplace=True)
    df.reset_index()
    return df.conf.mean()

# %%
def deskew(image):
    '''deskew the image'''
    gray = cv2.bitwise_not(image)
    temp_arr = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]
    coords = np.column_stack(np.where(temp_arr > 0))
    angle = cv2.minAreaRect(coords)[-1]
    if angle < -45:
        angle = -(90 + angle)
    else:
        angle = -angle
    (h, w) = image.shape[:2]
    center = (w // 2, h // 2)
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(image, M, (w, h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
    return rotated

# %%
'''
Main part of OCR:
pages_df: save extracted text for each pdf file, index by page
OCR_dic : dict for saving df of each pdf, filename is the key
'''

def extract_text_with_ocr(file_list, dir_source="."):
    OCR_dic={} 
    for file in file_list:
        if file.endswith(".pdf"):
            # convert pdf into image
            print(os.path.join(dir_source + "/" + file))
            pdf_file = convert_from_bytes(open(os.path.join(dir_source + "/" + file), 'rb').read())
            # create a df to save each pdf's text
            pages_df = pd.DataFrame(columns=['conf','text'])
            for (i,page) in enumerate(pdf_file) :
                try:
                    # transfer image of pdf_file into array
                    page_arr = np.asarray(page)
                    # transfer into grayscale
                    page_arr_gray = cv2.cvtColor(page_arr,cv2.COLOR_BGR2GRAY)
                    # deskew the page
                    page_deskew = deskew(page_arr_gray)
                    # cal confidence value
                    page_conf = get_conf(page_deskew)
                    # extract string 
                    pages_df = pd.concat([pages_df, pd.DataFrame([{'conf': page_conf,'text': pytesseract.image_to_string(page_deskew)}])], ignore_index=True)
                except:
                    # if can't extract then give some notes into df
                    pages_df =  pd.concat([pages_df, pd.DataFrame([{'conf': -1,'text': 'N/A'}])], ignore_index=True)
                    continue
            # save df into a dict with filename as key        
            OCR_dic[file]=pages_df
            print('{} is done'.format(file))
    return OCR_dic

# %%
source_dir = "./output_pdfs"

# %%
from os import listdir
from os.path import isfile, join

# %%
files = [f for f in listdir(source_dir) if isfile(join(source_dir, f))]

# %%
ocr = extract_text_with_ocr(files, source_dir)
# Out:
# ./output_pdfs/New_working doc_RFP.pdf
# New_working doc_RFP.pdf is done
# ./output_pdfs/Reference_Jibestream - responses.pdf
# Reference_Jibestream - responses.pdf is done
# ./output_pdfs/Jibestream responses to MemorialCare Questions.pdf
# Jibestream responses to MemorialCare Questions.pdf is done
# ./output_pdfs/Answers to questions.pdf
# Answers to questions.pdf is done
# ./output_pdfs/Response-RFP 956.pdf
# Response-RFP 956.pdf is done
# ./output_pdfs/16.07Jibestream Answers_IngkaQuestionnaire.pdf
# 16.07Jibestream Answers_IngkaQuestionnaire.pdf is done
# ./output_pdfs/Siemens_AAH RFP Submission - Location Based Services 2-22-19.pdf
# Siemens_AAH RFP Submission - Location Based Services 2-22-19.pdf is done
# ./output_pdfs/Jibestream response V1.pdf
# Jibestream response V1.pdf is done
# ./output_pdfs/Responses to Jibestream questions 2020-02-18.pdf
# Responses to Jibestream questions 2020-02-18.pdf is done
# ./output_pdfs/Answered-Inpixon New Supplier & Service[2] DW.pdf
# Answered-Inpixon New Supplier & Service[2] DW.pdf is done

# %%
ocr
# Out:
# {'New_working doc_RFP.pdf':          conf                                               text
#  0   54.623063  aoc\nech © 941 AN, Fr Oo 3:28 pe aC\nCancet oo...
#  1   95.797235  Executive Summary\n\nSonae Sierra is seeking p...
#  2   89.485972  ABOUT JIBESTREAM\n\nJibestream is the premier ...
#  3   91.209774  Jibestream’s Notable Clients\n\nWestfield\n\n|...
#  4   86.269008  Commercially Deployed Examples (Retail)\n\nOne...
#  5   95.028154  Scope of Work\n\nFRONTEND REQUIREMENTS\n\nREQ ...
#  6   88.418675  REQ 1.7 Search per store, tag, brand, category...
#  7   91.118370  [7] Centrepoint ]\n\n@e—9 Ko\n\nAbercrombie .....
#  8   91.275464  Turn by Turn indoor navigation is fully compat...
#  9   94.685586  See image below from our AR demo:\n\nREQ 1.12 ...
#  10  90.912575  OAKBROOK CENTER\n\n‘A GOP PROPERTY\n\nSTORES &...
#  11  86.866949  Jibestream allows you to add any object to the...
#  12  87.050246  REQ 2.3 Temporary changes to the floor plan: F...
#  13  84.035828  Map Team > Dovercourt > Map Editor\n\nLayers\n...
#  14  94.363749  Download Map\n\nREQ 2.6 User Level and Permiss...
#  15  93.994981  Jibestream CMS allows you to make Real-Time ch...
#  16  91.201175  Jibestream Active (‘Swagger’) documentation: h...
#  17  78.251618                                @ JIBESTREAM\n\n1\n
#  18  94.753629  Jibestream Deliverables (POC)\n\nThe developme...
#  19  86.426509  6 JIBESTREAM\n\nVinay lyer, Account Executive\...,
#  'Reference_Jibestream - responses.pdf':          conf                                               text
#  0   94.700848  Project name: Kaleida Health - https://www.kal...
#  1   94.310115  o invest in a future proof solution that could...
#  2   83.918505  MyKaleida\n\nFind Your Way\n\ny, A Use our way...
#  3   86.320374  <) MyKaleida\n\nOishei Children's Outpatient C...
#  4   93.701610  eevee ROGERS F 12:52 PM\n\n~~ — y\n\nBlue-dot ...
#  5   93.171920  Type of project (new, redesign, or enhancement...
#  6   96.034786  Email: bdecicco@kaleidahealth.org\nPhone: (716...
#  7   72.527915  Screen capture of several aspects of completed...
#  8   94.642887  Jibestream professional services on the projec...
#  9   95.020322  projects, and describe their roles in those pr...
#  10  84.378950  welcome page, search functions, parking, KIOSK...
#  11  96.225976   Use floor picker to see next\nlevel on route\n\n
#  12  95.825585  Cancel MAP\n5\n\nHOME\n\nDescription of profes...
#  13  95.491573  Westtield s brand.\n\nSupport was provided for...
#  14  94.022566  projects, and describe their roles in those pr...,
#  'Jibestream responses to MemorialCare Questions.pdf':         conf                                               text
#  0  90.331274  1. What other health systems are you currently...
#  1  95.513015  4. How many employees do you have?\n\n37\n\nIm...
#  2  85.046325  Jibestream CMS offers a feature called ‘Map Ed...
#  3  91.295758  TM. WYEIGL UVES YUU! SUPPVIL Led TI SYotelll M...
#  4  92.588370  2) Jjibestream can leverage your existing app ...
#  5  89.832482  JINE StI ca HES IU MUTT UStlh ahi Fu\n\nof int...
#  6  91.242219  21. Where will our data be hosted at? (Cloud, ...
#  7  85.762115  JY ETO VETS SUIT, TEMS Way YM\n\nTOV ME TLE EA...,
#  'Answers to questions.pdf':         conf                                               text
#  0  82.821264  i. IS there a scope Of work Of reature list ao...
#  1  89.492740  @ conse J\n\nHarvey Nichols (0)\nDubai Next\n\...
#  2  94.592873  s an Out of the Box feature, deployed in 1000+...
#  3  92.625646  =e,\n\nL I\n\nb. Let us know what is involved ...
#  4  94.495624  Vinay Iyer | Enterprise Account Executive\nJIB...,
#  'Response-RFP 956.pdf':          conf                                               text
#  0   92.849816  camh\n\nmental health is health\n\nCENTRE FOR ...
#  1   88.541412  TABLE OF CONTENTS\n\nPART 1 —- INTRODUCTION .\...
#  2   95.134217  PART 1 — INTRODUCTION\n1.1. INVITATION TO PROP...
#  3   93.417582  PART 2 — SCOPE OF WORK (SOW)\n2.1. DEFINITION ...
#  4   95.077824  PART 3 — SUBMISSION AND EVALUATION OF PROPOSAL...
#  5   94.021067  excluding rate the Rate Bid Form (Appendix C),...
#  6   93.528808  Proponents should refer to the Rate Bid Form a...
#  7   94.945877  PART 4 - TERMS AND CONDITIONS OF THE RFP PROCE...
#  8   94.857337  (Appendix B), proponents should confirm their ...
#  9   95.151860  4.3.5 Failure to Enter Into Agreement\n\nPropo...
#  10  94.800069  (b) is not to be used for any purpose other th...
#  11  94.726176  4.7.4 Disqualification for Misrepresentation\n...
#  12  94.570695  APPENDIX A — FORM OF AGREEMENT\n\nMaster Servi...
#  13  94.869212  APPENDIX B — SUBMISSION FORM\n\nProponent Info...
#  14  96.118672  proponent acknowledges that any inaccurate, mi...
#  15  96.021436  Brief Description of Individual’s Job Function...
#  16  94.324854  APPENDIX C —- RATE BID FORM\n\nProfessional De...
#  17  95.361544  APPENDIX D — REFERENCE FORM\n\nEach proponent ...
#  18  94.988342  Date Work Undertaken: August 1, 2018\n\nNature...
#  19  95.645966  Proponent organizations should demonstrate pre...
#  20  95.995002  accommodations, etc. It is recommended that th...
#  21  94.946090  ITEMNO. | REQUIREMENTS iNiris Gir\n\nCRITERIA\...
#  22  85.365144  Blue-dot\n\nMap Data\n{zones room names: et)\n...
#  23  95.337442  Jibestream also has experience working with a ...
#  24  92.610958  located in our Toronto office). Dave to add de...
#  25  93.742781  If the product you are proposing is fairly new...
#  26  94.437025  Please provide your answers to the topics iden...
#  27  90.992362  Please provide your response to the topics ide...
#  28  95.009854  indicated below are for RFP planning purposes ...
#  29  94.778915  The following is an overview of the categories...
#  30  93.998568  A proponent who bids $150.00 receives 80% of t...
#  31  88.244976  ANNEXURE | —- FUNCTIONAL REQUIREMENTS\n\n1.0 |...
#  32  89.090183  3.0\n\nFEATURES\n\nPlease provide details/expl...
#  33  87.271914  4-2 \Admin user should have User Management\n\...
#  34  83.470803  InfoSec team that develops our policies and\np...
#  35  88.675795  to deploy many other complex use-cases such as...
#  36  89.793465  Please include support coverage and service __...
#  37  88.082358  Each customer on the Jibestream platform is a ...
#  38  95.632077  ANNEXURE II - PROFESSIONAL SERVICES REQUIREMEN...
#  39  95.021063  Mapping process — creation of layer based dyna...
#  40  94.838760  }) How long will each session be?\n\n60 to 90 ...
#  41  94.534362  Jibestream’s product trainings are extremely k...
#  42  93.826718  ANNEXURE III - MAINTENANCE AND SUPPORT SERVICE...
#  43  94.664805  a) Asingle point of contact is required for al...,
#  '16.07Jibestream Answers_IngkaQuestionnaire.pdf':         conf                                               text
#  0  81.692054  Cid) alia\n\nto easier visualize!\nit\n\nconst...
#  1  80.454904  As a leasing co-_ ||technical\n12 pworker t wa...
#  2  79.600558  centre\n\n5=All\n[As a Marketing _ technical W...
#  3  82.850686  This is one of my favourite use-cases! This\n\...
#  4  86.099017  colour when you tap on a layer, or tor\n\nrole...
#  5  52.280247                          Pip A Eee eae Seema |\n\n,
#  'Siemens_AAH RFP Submission - Location Based Services 2-22-19.pdf':          conf                                               text
#  0   94.336624  Unnamed:\n\nUnnamed: 1\n\n0\n\n0\n\n1\n\n2\n\n...
#  1   88.802932  the Vendor approach completing this workbook.\...
#  2   92.605314  Instructions for Completion of the Questionnai...
#  3   94.859578  Definitions: Nonmandatory Indoor Wayfinding Pl...
#  4   93.802525  |National Institutes of Health "Quadruple Aim"...
#  5   88.447040  ad\n\nsolution\n(pertaining to\nthe solution\n...
#  6   88.310423  Vendor\n\nInformation\n\nUnnamed: 1\n\n‘Unname...
#  7   87.646880  reference.\n\neee eee\n\nClient\n(Company\n\n‘...
#  8   89.725450  [References Unnamed: 1 Unnamed: 2\nAfter a suc...
#  9   84.585882  Please provide vee SHOW IT ~ ail IONS Hap. POM...
#  10  88.589273  Jibestream maps are downloaded and cached in t...
#  11  86.660962  building within the venue. \n\n 1 his use case...
#  12  89.107756  solution provide\n\nend system including staff...
#  13  89.445763  Unnamed:\n\n33)\n\nProduct Unnamed: 1 2 Unname...
#  14  90.359580  Please provide your pote ed HILO HICLIBCHL, HI...
#  15  89.197497  Do you provide 3D\n\nland accessibility standa...
#  16  91.485181  Map\nCreation\n\nand\nMaintenance’\n\nUnnamed:...
#  17  92.197015  VOUlNpany >\n\nlapproach to\nhardware |A big d...
#  18  88.295445  6 //5.0 without any =| Yes PN Or\nprerequisite...
#  19  92.055269  installed? the lights or as a standalone ("fix...
#  20  86.863382  beacons?\n\n27,\n\n22.0\n\nHow is battery\nper...
#  21  90.904886  solution use\n\nany other\n37||32.0 technologi...
#  22  91.956550  Infrastructure\n\nUnnamed: 1\n\n‘Unnamed:\n2\n...
#  23  83.603262  development and HSS LO UGUR dG THIOMIMOL PerUn...
#  24  88.254313  aal15.0 (What standard reports By having acces...
#  25  86.167304  ithe proposed solution\ninterface with?\n\nPUL...
#  26  82.666243  management software\ndevelopment and delivery ...
#  27  86.279526  WAPIALAULOL,\n3 }/1.1\n41.2.\n5 |/1.3\n6 |/1.4...
#  28  86.819113  JPILVALY SULEWALY UP VOLOVIIeTt OPOTHOHS 1S TS...
#  29        NaN
#  30  92.395015  Implementation\n\nCosts\n\nUnnamed: 1\n\n‘Unna...
#  31  88.042159  Ula CHIPNASIZeS\n\nenterprise clients like AAH...,
#  'Jibestream response V1.pdf':         conf                                               text
#  0  94.988975  Does the application provide real time positio...
#  1  95.897071  Will the organization be able to manage or upd...,
#  'Responses to Jibestream questions 2020-02-18.pdf':         conf                                               text
#  0  94.816820  Questions towards Jibestream as preparation fo...
#  1  96.177357  specified floor area etc. So a customer guidan...
#  2  92.849741  e 25 hours - $5,000\ne 50 hours - $9,000\n\ne ...
#  3  94.779352  Additional questions\n\nWhat is the underlying...
#  4  96.652706  We recommend that for any “Net New” store, we ...,
#  'Answered-Inpixon New Supplier & Service[2] DW.pdf':         conf                                               text
#  0  90.836990  tnat specializes In Capturing, interpreting\na...
#  1  95.885706  Service Contact: Jon Barnett\n\nService Contac...}

# %%
ocr["New_working doc_RFP.pdf"]
# Out:
#          conf                                               text
# 0   54.623063  aoc\nech © 941 AN, Fr Oo 3:28 pe aC\nCancet oo...
# 1   95.797235  Executive Summary\n\nSonae Sierra is seeking p...
# 2   89.485972  ABOUT JIBESTREAM\n\nJibestream is the premier ...
# 3   91.209774  Jibestream’s Notable Clients\n\nWestfield\n\n|...
# 4   86.269008  Commercially Deployed Examples (Retail)\n\nOne...
# 5   95.028154  Scope of Work\n\nFRONTEND REQUIREMENTS\n\nREQ ...
# 6   88.418675  REQ 1.7 Search per store, tag, brand, category...
# 7   91.118370  [7] Centrepoint ]\n\n@e—9 Ko\n\nAbercrombie .....
# 8   91.275464  Turn by Turn indoor navigation is fully compat...
# 9   94.685586  See image below from our AR demo:\n\nREQ 1.12 ...
# 10  90.912575  OAKBROOK CENTER\n\n‘A GOP PROPERTY\n\nSTORES &...
# 11  86.866949  Jibestream allows you to add any object to the...
# 12  87.050246  REQ 2.3 Temporary changes to the floor plan: F...
# 13  84.035828  Map Team > Dovercourt > Map Editor\n\nLayers\n...
# 14  94.363749  Download Map\n\nREQ 2.6 User Level and Permiss...
# 15  93.994981  Jibestream CMS allows you to make Real-Time ch...
# 16  91.201175  Jibestream Active (‘Swagger’) documentation: h...
# 17  78.251618                                @ JIBESTREAM\n\n1\n
# 18  94.753629  Jibestream Deliverables (POC)\n\nThe developme...
# 19  86.426509  6 JIBESTREAM\n\nVinay lyer, Account Executive\...

# %%
list(ocr.keys())
# Out:
# ['New_working doc_RFP.pdf',
#  'Reference_Jibestream - responses.pdf',
#  'Jibestream responses to MemorialCare Questions.pdf',
#  'Answers to questions.pdf',
#  'Response-RFP 956.pdf',
#  '16.07Jibestream Answers_IngkaQuestionnaire.pdf',
#  'Siemens_AAH RFP Submission - Location Based Services 2-22-19.pdf',
#  'Jibestream response V1.pdf',
#  'Responses to Jibestream questions 2020-02-18.pdf',
#  'Answered-Inpixon New Supplier & Service[2] DW.pdf']

# %%
content = ""

# %%
for key in ocr.keys():
    for index, row in ocr[key].iterrows():
        if row['conf'] > 80:
            content += row['text']

# %%
parse = content.replace("\n", " ")

# %%
#open text file
text_file = open("./train.pdf", "w")

# %%
#write string to file
text_file.write(parse)
#close file
text_file.close()
